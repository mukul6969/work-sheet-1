# %% [markdown]
# # PYTHON - WORKSHEET 1

# %%
1. (C)
2. (B)
3. (C)
4. (A)
5. (D)
6. (C)
7. (A)
8. (C)
9. (A), (C)
10. (A), (B)

# %%
11. # Program to find the factorial of a no

n=int(input("enter the number to find the factorial"))
def fact(n):
    
    if n==1 :
        return 1
    else :
        return n*fact(n-1)
    
if n<0 :
    print(" number is negative . factorial not possible")
elif n==0:
    print("The factorial is ",1)
else:
     print("The factorial is ",fact(n))
# Out:
# enter the number to find the factorial6
# ('The factorial is ', 720)

# %%
#ans12 Program to check whether entered number is a prime number or a composite number

n=int(input('enter the number'))
if n==0 or n==1:
    print("neither prime nor composite")
else:
    k=[]
    for i in range(1,n):
        if n%i==0:
            k.append(i)
    if len(k)<=2:
        print("Number is prime")
        
    else :
        print("Number is composite")
# Out:
# enter the number5
# Number is prime

# %% [markdown]
# 13. **Answer is as follows :**

# %%
# Program to check if the entered string is palindrome or not

string=input("Enter the string")
rev_string=""
for i in range(1,len(string)+1):
    rev_string=rev_string+string.lower()[-i]
if rev_string==string:
    print("the string is palindrome")
else :
    print("the string is not palindrome")
# Out:
# Enter the string level
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-47e4085cb196> in <module>()
#       1 # Program to check if the entered string is palindrome or not
#       2
# ----> 3 string=input("Enter the string")
#       4 rev_string=""
#       5 for i in range(1,len(string)+1):
#
# C:\Users\Mukul Dhamija\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <lambda>(prompt)
#     174             self._sys_eval_input = builtin_mod.input
#     175             builtin_mod.raw_input = self.raw_input
# --> 176             builtin_mod.input = lambda prompt='': eval(self.raw_input(prompt))
#     177         self._save_getpass = getpass.getpass
#     178         getpass.getpass = self.getpass
#
# C:\Users\Mukul Dhamija\Anaconda2\lib\site-packages\ipykernel\ipkernel.pyc in <module>()
#
# NameError: name 'level' is not defined

# %%
 #ans14 Program to find the length of hypotenuse of a right angled triangle

import math
a=int(input("enter the base of the right angled triangle"))
b=int(input("enter the perpendicular of the right angled triangle"))
print("the length of hypotenuse is ",math.sqrt(a**2+b**2))

# %%
#ans15 Program to find the frequency of each character present in the entered string

string=input("Enter the string")
freq=dict()
for i in string :
    if i in freq.keys():
        freq[i]=freq[i]+1
    else :
        freq[i]=1
print(" The frequencies of characters in the string are", freq)
